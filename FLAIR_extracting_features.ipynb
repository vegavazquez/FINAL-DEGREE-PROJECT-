# %%
import radiomics as rd
import numpy as np 
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers 
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from skimage.io import imread
from skimage.io import imread_collection
import os
import gzip
import shutil  #copyfile, marcar el path del archivo original y el nombre y el path donde lo que quieres copiar 
import nibabel as nib
import ntpath
from pathlib import Path

import glob

# %%
data_dir = '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR'
path1 = os.path.join(data_dir, '*.nii.gz')
list1=[]
collection1 = imread_collection(path1)
""""for image in collection1.files:
    img1= nib.load(image)
    images_T1.append(img1)
print(collection1)"""
for image in collection1.files:
    list1.append(image)
    print(list1)


masks=[]
data_dir_mask='/Users/vegavazquez/Downloads/pruebas_dest/MASKS'
list2=[]
path2 = os.path.join(data_dir_mask, '*.nii.gz')
collection2 = imread_collection(path2)
for image in collection2.files:
    list2.append(image)
    print(list2)
""""for image in collection2.files:
    img2= nib.load(image)
    masks.append(img2)
    print(collection2)"""
# Out:
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0085_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0085_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0090_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0085_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0090_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0099_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0085_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0090_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0099_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0106_FLAIR.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-
# ['EGD-0004', 'EGD-0008', 'EGD-0011', 'EGD-0020', 'EGD-0022', 'EGD-0024', 'EGD-0029', 'EGD-0033', 'EGD-0041', 'EGD-0055', 'EGD-0057', 'EGD-0068', 'EGD-0072', 'EGD-0073', 'EGD-0075', 'EGD-0080', 'EGD-0085', 'EGD-0090', 'EGD-0099', 'EGD-0106', 'EGD-0107', 'EGD-0115', 'EGD-0118', 'EGD-0122', 'EGD-0123', 'EGD-0128', 'EGD-0137', 'EGD-0143', 'EGD-0144', 'EGD-0145', 'EGD-0161', 'EGD-0162', 'EGD-0165', 'EGD-0177', 'EGD-0185', 'EGD-0186', 'EGD-0187', 'EGD-0188', 'EGD-0192', 'EGD-0193', 'EGD-0194', 'EGD-0196', 'EGD-0197', 'EGD-0202', 'EGD-0208', 'EGD-0211', 'EGD-0214', 'EGD-0217', 'EGD-0226', 'EGD-0229', 'EGD-0230', 'EGD-0233', 'EGD-0234', 'EGD-0236', 'EGD-0240', 'EGD-0241', 'EGD-0243', 'EGD-0244', 'EGD-0253', 'EGD-0268', 'EGD-0280', 'EGD-0286', 'EGD-0297', 'EGD-0306', 'EGD-0309', 'EGD-0312', 'EGD-0319', 'EGD-0321', 'EGD-0330', 'EGD-0332', 'EGD-0337', 'EGD-0338', 'EGD-0340', 'EGD-0344', 'EGD-0349', 'EGD-0351', 'EGD-0352', 'EGD-0356', 'EGD-0357', 'EGD-0363', 'EGD-0369', 'EGD-0377', 'EGD-0378', 'EGD-0382', 'EGD-0387', 'EGD-0389', 'EGD-0390', 'EGD-0394', 'EGD-0401', 'EGD-0410', 'EGD-0411', 'EGD-0415', 'EGD-0417', 'EGD-0420', 'EGD-0421', 'EGD-0426', 'EGD-0434', 'EGD-0439', 'EGD-0450', 'EGD-0461', 'EGD-0472', 'EGD-0474', 'EGD-0479', 'EGD-0480', 'EGD-0486', 'EGD-0487', 'EGD-0490', 'EGD-0495', 'EGD-0499', 'EGD-0502', 'EGD-0505', 'EGD-0508', 'EGD-0509', 'EGD-0511', 'EGD-0512', 'EGD-0514', 'EGD-0515', 'EGD-0516', 'EGD-0521', 'EGD-0526', 'EGD-0531', 'EGD-0537', 'EGD-0541', 'EGD-0545', 'EGD-0553', 'EGD-0564', 'EGD-0565', 'EGD-0567', 'EGD-0568', 'EGD-0572', 'EGD-0577', 'EGD-0579', 'EGD-0585', 'EGD-0595', 'EGD-0600', 'EGD-0601', 'EGD-0604', 'EGD-0606', 'EGD-0611', 'EGD-0612', 'EGD-0625', 'EGD-0629', 'EGD-0631', 'EGD-0636', 'EGD-0647', 'EGD-0656', 'EGD-0661', 'EGD-0664', 'EGD-0668', 'EGD-0669', 'EGD-0675', 'EGD-0689', 'EGD-0692', 'EGD-0700', 'EGD-0705', 'EGD-0709', 'EGD-0710', 'EGD-0720', 'EGD-0725', 'EGD-0728', 'EGD-0730', 'EGD-0744', 'EGD-0753', 'EGD-0757', 'EGD-0758', 'EGD-0762', 'EGD-0771', 'EGD-0772', 'EGD-0773']

# %%
import pandas as pd
""""df = pd.read_csv("Names.csv", header=None)
df["new_column"] = ""
df.to_csv("Names.csv", index=True)
df.to_csv("Names.csv", header=['ID','Image','Mask'], index=True)"""
import csv
rows = zip(ID, list1, list2)

with open('FLAIR_path.csv', "w") as f:
    writer = csv.writer(f)
    for row in rows:
        writer.writerow(row)


df = pd.read_csv("FLAIR_path.csv", header=None)
df.to_csv("FLAIR_path.csv", index=True)
df.to_csv("FLAIR_path.csv", header=['ID','Image','Mask'], index=True)

# %%
# Additonally, store the location of the example parameter file, stored in \pyradiomics\bin
paramPath = '/Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml'
inputCSV= '/Users/vegavazquez/Downloads/TFG/FLAIR_path.csv'
print ("Parameter file, absolute path:", os.path.abspath(paramPath))
print ("Paths file, absolute path:", os.path.abspath(inputCSV))
# Out:
# Parameter file, absolute path: /Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml
# Paths file, absolute path: /Users/vegavazquez/Downloads/TFG/FLAIR_path.csv

# %%
outPath = '/Users/vegavazquez/Downloads/TFG'
outputFilepath = os.path.join(outPath, 'radiomics_features3.csv')
progress_filename = os.path.join(outPath, 'pyrad_log.txt')
print(outputFilepath)
os.path.exists(outputFilepath)
#os.path.exists(progress_filename)
# Out:
# /Users/vegavazquez/Downloads/TFG/radiomics_features3.csv
# True

# %%
from __future__ import print_function

import logging
import os

import pandas
import SimpleITK as sitk

import radiomics
from radiomics import featureextractor

# %%
# Configure logging
rLogger = logging.getLogger('radiomics')
# Create handler for writing to log file
handler = logging.FileHandler(filename=progress_filename, mode='w')
handler.setFormatter(logging.Formatter('%(levelname)s:%(name)s: %(message)s'))
rLogger.addHandler(handler)

# %%
# Initialize logging for batch log messages
logger = rLogger.getChild('batch')
# Set verbosity level for output to stderr (default level = WARNING)
radiomics.setVerbosity(logging.INFO)
logger.info('pyradiomics version: %s', radiomics.__version__)
logger.info('Loading CSV')
# Out:
# pyradiomics version: v3.0.1
# Loading CSV

# %%
try:
    # Use pandas to read and transpose ('.T') the input data
    # The transposition is needed so that each column represents one test case. This is easier for iteration over
    # the input cases
    flists = pandas.read_csv(inputCSV).T
except Exception:
    logger.error('CSV READ FAILED', exc_info=True)
    exit(-1)

# %%
from radiomics import firstorder, getTestCase, glcm, glrlm, glszm, imageoperations, shape

# %%
logger.info('Loading Done')
logger.info('Patients: %d', len(flists.columns)) #ALL PATIENTS
# Out:
# Loading Done
# Patients: 169

# %%
if os.path.isfile(paramPath):
    extractor = featureextractor.RadiomicsFeatureExtractor(paramPath)
else:  # Parameter file not found, use hardcoded settings instead
    settings = {}
    settings['binWidth'] = 25
    settings['resampledPixelSpacing'] = None  # [3,3,3]
    settings['interpolator'] = sitk.sitkBSpline
    settings['enableCExtensions'] = True

    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    # extractor.enableInputImages(wavelet= {'level': 2})
# Out:
# Loading parameter file /Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml

# %%
logger.info('Enabled input images types: %s', extractor.enabledImagetypes)
logger.info('Enabled features: %s', extractor.enableFeatureClassByName)
logger.info('Current settings: %s', extractor.settings)
logger.info('show shape features: %s', extractor.enableAllFeatures)
# Out:
# Enabled input images types: {'Original': {}}
# Enabled features: <bound method RadiomicsFeatureExtractor.enableFeatureClassByName of <radiomics.featureextractor.RadiomicsFeatureExtractor object at 0x7fa8fac696d0>>
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'weightingNorm': None}
# show shape features: <bound method RadiomicsFeatureExtractor.enableAllFeatures of <radiomics.featureextractor.RadiomicsFeatureExtractor object at 0x7fa8fac696d0>>

# %%
# Instantiate a pandas data frame to hold the results of all patients
results = pandas.DataFrame()

# %%
import pandas as pd 
df=pd.read_csv(inputCSV)
df.head()
# Out:
#    Unnamed: 0        ID                                              Image  \
# 0           0  EGD-0004  /Users/vegavazquez/Downloads/pruebas_dest/FLAI...
# 1           1  EGD-0008  /Users/vegavazquez/Downloads/pruebas_dest/FLAI...
# 2           2  EGD-0011  /Users/vegavazquez/Downloads/pruebas_dest/FLAI...
# 3           3  EGD-0020  /Users/vegavazquez/Downloads/pruebas_dest/FLAI...
# 4           4  EGD-0022  /Users/vegavazquez/Downloads/pruebas_dest/FLAI...
#
#                                                 Mask
# 0  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 1  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 2  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 3  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 4  /Users/vegavazquez/Downloads/pruebas_dest/MASK...

# %%
for entry in flists:  # Loop over all columns (i.e. the test cases)
    logger.info("(%d/%d) Processing Patient (Image: %s, Mask: %s)",
                entry + 1,
                len(flists),
                flists[entry]['Image'],
                flists[entry]['Mask'])
    imageFilepath = flists[entry]['Image']
    maskFilepath = flists[entry]['Mask']
    label = flists[entry].get('ID', None)
    
    if str(label).isdigit():
        label = int(label)
    else:
        label = None
        
    if (imageFilepath is not None) and (maskFilepath is not None):
        featureVector = flists[entry]  # This is a pandas Series
        featureVector['Image'] = os.path.basename(imageFilepath)
        featureVector['Mask'] = os.path.basename(maskFilepath)
        try:
        # PyRadiomics returns the result as an ordered dictionary, which can be easily converted to a pandas Series
        # The keys in the dictionary will be used as the index (labels for the rows), with the values of the features
        # as the values in the rows.
            result = pandas.Series(extractor.execute(imageFilepath, maskFilepath, label))
            featureVector = featureVector.append(result)
        except Exception:
            logger.error('FEATURE EXTRACTION FAILED:', exc_info=True)
        # To add the calculated features for this case to our data frame, the series must have a name (which will be the
          # name of the column.
        featureVector.name = entry
          # By specifying an 'outer' join, all calculated features are added to the data frame, including those not
          # calculated for previous cases. This also ensures we don't end up with an empty frame, as for the first patient
          # it is 'joined' with the empty data frame.
        results = results.join(featureVector, how='outer')  # If feature extraction failed, results will be all NaN
    logger.info('Extraction complete, writing CSV')
  # .T transposes the data frame, so that each line will represent one patient, with the extracted features as columns
    results.T.to_csv(outputFilepath, index=False, na_rep='NaN')
    logger.info('CSV writing complete')
# Out:
# (1/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0004_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0004_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (2/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0008_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0008_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (3/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0011_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0011_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (4/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0020_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0020_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (5/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0022_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0022_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (6/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0024_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0024_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (7/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0029_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0029_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (8/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0033_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0033_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (9/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0041_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0041_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (10/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0055_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0055_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (11/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0057_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0057_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (12/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0068_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0068_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (13/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0072_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0072_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (14/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0073_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0073_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (15/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0075_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0075_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (16/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0080_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0080_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (17/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0085_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0085_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (18/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0090_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0090_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (19/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0099_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0099_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (20/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0106_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0106_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (21/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0107_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0107_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (22/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0115_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0115_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (23/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0118_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0118_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (24/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0122_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0122_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (25/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0123_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0123_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (26/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0128_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0128_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (27/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0137_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0137_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (28/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0143_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0143_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (29/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0144_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0144_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (30/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0145_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0145_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (31/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0161_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0161_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (32/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0162_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0162_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (33/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0165_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0165_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (34/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0177_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0177_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (35/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0185_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0185_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (36/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0186_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0186_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (37/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0187_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0187_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (38/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0188_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0188_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (39/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0192_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0192_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (40/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0193_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0193_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (41/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0194_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0194_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (42/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0196_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0196_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (43/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0197_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0197_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (44/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0202_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0202_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (45/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0208_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0208_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (46/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0211_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0211_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (47/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0214_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0214_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (48/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0217_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0217_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (49/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0226_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0226_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (50/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0229_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0229_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (51/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0230_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0230_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (52/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0233_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0233_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (53/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0234_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0234_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (54/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0236_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0236_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (55/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0240_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0240_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (56/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0241_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0241_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (57/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0243_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0243_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (58/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0244_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0244_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (59/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0253_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0253_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (60/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0268_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0268_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (61/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0280_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0280_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (62/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0286_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0286_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (63/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0297_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0297_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (64/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0306_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0306_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# ...
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (149/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0668_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0668_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (150/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0669_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0669_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (151/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0675_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0675_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (152/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0689_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0689_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (153/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0692_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0692_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (154/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0700_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0700_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (155/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0705_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0705_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (156/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0709_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0709_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (157/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0710_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0710_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (158/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0720_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0720_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (159/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0725_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0725_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (160/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0728_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0728_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (161/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0730_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0730_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (162/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0744_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0744_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (163/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0753_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0753_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (164/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0757_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0757_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (165/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0758_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0758_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (166/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0762_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0762_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (167/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0771_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0771_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (168/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0772_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0772_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (169/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0773_FLAIR.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0773_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_17049/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
