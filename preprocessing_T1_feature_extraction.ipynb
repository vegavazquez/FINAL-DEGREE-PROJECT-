# %%
import radiomics as rd
import numpy as np 
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import layers 
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from skimage.io import imread
from skimage.io import imread_collection
import os
import gzip
import shutil  #copyfile, marcar el path del archivo original y el nombre y el path donde lo que quieres copiar 
import nibabel as nib
import ntpath
from pathlib import Path
import pandas as pd
import glob

# %%
rootdir='/Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/'

outpath='/Users/vegavazquez/Downloads/pruebas_dest/T1/'

outpath2='/Users/vegavazquez/Downloads/pruebas_dest/T2/'

outpath3='/Users/vegavazquez/Downloads/pruebas_dest/FLAIR/'

outpath4= '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/'

outpath5= '/Users/vegavazquez/Downloads/pruebas_dest/GD/'

# %%
for root, dirs, files in os.walk(rootdir):
    for filename in files:
        if not filename.endswith('.nii.gz'): #ignoring the DS_Store directory 
            continue
        
        old_name = os.path.join(os.path.abspath(root), filename)
        
        
        dirname=old_name.split('/')[5]
        #print(dirname)
        
        file_new_name=dirname+ "_" +filename 
        #print(file_new_name)
        dest= root + '/' + file_new_name
       
        os.rename(old_name, dest)

# %%
for root, dirs, files in os.walk(rootdir):
    for filename in files:
        if not filename.endswith('.nii.gz'): #ignoring the DS_Store directory 
            continue
        new_name = os.path.join(os.path.abspath(root), filename)
        base, extension = os.path.splitext(filename)
        print(base)
        print(extension)
        if 'T1.nii' in base:
            new_destination= outpath  + filename
            print(new_destination)
            shutil.copy(new_name, new_destination)
            print ("Copied", new_name, "as", new_destination)
        elif 'T2.nii' in base:
            new_destination2= outpath2+ filename
            print(new_destination2)
            shutil.copy(new_name, new_destination2)
            print ("Copied", new_name, "as", new_destination2)
        elif 'FLAIR.nii' in base:
            new_destination3= outpath3+ filename
            print(new_destination3)
            shutil.copy(new_name, new_destination3)
            print ("Copied", new_name, "as", new_destination3)
        elif 'MASK.nii' in base:
            new_destination4= outpath4+ filename
            print(new_destination4)
            shutil.copy(new_name, new_destination4)
            print ("Copied", new_name, "as", new_destination4)
        else:
            new_destination5= outpath5+ filename
            print(new_destination5)
            shutil.copy(new_name, new_destination5)
            print ("Copied", new_name, "as", new_destination5)
# Out:
# EGD-0185_FLAIR.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0185_FLAIR.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0185/MR_EGD-0185/4_FLAIR/NIFTI/EGD-0185_FLAIR.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0185_FLAIR.nii.gz
# EGD-0185_T1GD.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0185_T1GD.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0185/MR_EGD-0185/2_T1GD/NIFTI/EGD-0185_T1GD.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0185_T1GD.nii.gz
# EGD-0185_MASK.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0185_MASK.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0185/MR_EGD-0185/5_MASK/NIFTI/EGD-0185_MASK.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0185_MASK.nii.gz
# EGD-0185_T2.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0185_T2.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0185/MR_EGD-0185/3_T2/NIFTI/EGD-0185_T2.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0185_T2.nii.gz
# EGD-0185_T1.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0185_T1.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0185/MR_EGD-0185/1_T1/NIFTI/EGD-0185_T1.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0185_T1.nii.gz
# EGD-0515_FLAIR.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0515_FLAIR.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0515/MR_EGD-0515/4_FLAIR/NIFTI/EGD-0515_FLAIR.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0515_FLAIR.nii.gz
# EGD-0515_T1GD.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0515_T1GD.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0515/MR_EGD-0515/2_T1GD/NIFTI/EGD-0515_T1GD.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0515_T1GD.nii.gz
# EGD-0515_MASK.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0515_MASK.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-
MASK.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0567_MASK.nii.gz
# EGD-0567_T2.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0567_T2.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0567/MR_EGD-0567/3_T2/NIFTI/EGD-0567_T2.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0567_T2.nii.gz
# EGD-0567_T1.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0567_T1.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0567/MR_EGD-0567/1_T1/NIFTI/EGD-0567_T1.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0567_T1.nii.gz
# EGD-0309_FLAIR.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0309_FLAIR.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0309/MR_EGD-0309/4_FLAIR/NIFTI/EGD-0309_FLAIR.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/FLAIR/EGD-0309_FLAIR.nii.gz
# EGD-0309_T1GD.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0309_T1GD.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0309/MR_EGD-0309/2_T1GD/NIFTI/EGD-0309_T1GD.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/GD/EGD-0309_T1GD.nii.gz
# EGD-0309_MASK.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0309_MASK.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0309/MR_EGD-0309/5_MASK/NIFTI/EGD-0309_MASK.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0309_MASK.nii.gz
# EGD-0309_T2.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0309_T2.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0309/MR_EGD-0309/3_T2/NIFTI/EGD-0309_T2.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T2/EGD-0309_T2.nii.gz
# EGD-0309_T1.nii
# .gz
# /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0309_T1.nii.gz
# Copied /Users/vegavazquez/Downloads/TFG_FINAL_IMAGES/EGD-0309/MR_EGD-0309/1_T1/NIFTI/EGD-0309_T1.nii.gz as /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0309_T1.nii.gz

# %% [markdown]
# # First order Features

# %% [markdown]
# First-order statistics describe the distribution of voxel intensities within the image region defined by the mask through commonly used and basic metrics.

# %%
## images_T1=[]
data_dir = '/Users/vegavazquez/Downloads/pruebas_dest/T1'
path1 = os.path.join(data_dir, '*.nii.gz')
list1=[]
collection1 = imread_collection(path1)
""""for image in collection1.files:
    img1= nib.load(image)
    images_T1.append(img1)
print(collection1)"""
for image in collection1.files:
    list1.append(image)
    print(list1)


masks=[]
data_dir_mask='/Users/vegavazquez/Downloads/pruebas_dest/MASKS'
list2=[]
path2 = os.path.join(data_dir_mask, '*.nii.gz')
collection2 = imread_collection(path2)
for image in collection2.files:
    list2.append(image)
    print(list2)
""""for image in collection2.files:
    img2= nib.load(image)
    masks.append(img2)
print(collection2)"""
# Out:
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0057_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0057_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0068_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0057_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0068_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0072_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0057_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0068_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0072_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0073_T1.nii.gz']
# ['/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-
MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0115_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0118_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0122_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0123_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0128_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0137_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0143_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0144_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0145_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0161_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0162_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0165_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0177_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0185_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0186_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0187_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0188_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0192_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0193_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0194_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0196_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0197_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0202_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0208_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0211_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0214_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0217_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0226_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0229_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0230_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0233_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0234_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0236_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0240_MASK.nii.gz', '/Users/vegavazquez/Downloads/pruebas_d ...
# '"for image in collection2.files:\n    img2= nib.load(image)\n    masks.append(img2)\nprint(collection2)'

# %%
#creating a list of ID
import pandas
column_names = ["ID"]

DataFrame=pandas.read_csv('ID.csv', names=column_names)
print(DataFrame)
ID=DataFrame.ID.to_list()
ID.pop(0)
print(ID)
# Out:
#            ID
# 0     Subject
# 1    EGD-0004
# 2    EGD-0008
# 3    EGD-0011
# 4    EGD-0020
# ..        ...
# 165  EGD-0758
# 166  EGD-0762
# 167  EGD-0771
# 168  EGD-0772
# 169  EGD-0773
#
# [170 rows x 1 columns]
# ['EGD-0004', 'EGD-0008', 'EGD-0011', 'EGD-0020', 'EGD-0022', 'EGD-0024', 'EGD-0029', 'EGD-0033', 'EGD-0041', 'EGD-0055', 'EGD-0057', 'EGD-0068', 'EGD-0072', 'EGD-0073', 'EGD-0075', 'EGD-0080', 'EGD-0085', 'EGD-0090', 'EGD-0099', 'EGD-0106', 'EGD-0107', 'EGD-0115', 'EGD-0118', 'EGD-0122', 'EGD-0123', 'EGD-0128', 'EGD-0137', 'EGD-0143', 'EGD-0144', 'EGD-0145', 'EGD-0161', 'EGD-0162', 'EGD-0165', 'EGD-0177', 'EGD-0185', 'EGD-0186', 'EGD-0187', 'EGD-0188', 'EGD-0192', 'EGD-0193', 'EGD-0194', 'EGD-0196', 'EGD-0197', 'EGD-0202', 'EGD-0208', 'EGD-0211', 'EGD-0214', 'EGD-0217', 'EGD-0226', 'EGD-0229', 'EGD-0230', 'EGD-0233', 'EGD-0234', 'EGD-0236', 'EGD-0240', 'EGD-0241', 'EGD-0243', 'EGD-0244', 'EGD-0253', 'EGD-0268', 'EGD-0280', 'EGD-0286', 'EGD-0297', 'EGD-0306', 'EGD-0309', 'EGD-0312', 'EGD-0319', 'EGD-0321', 'EGD-0330', 'EGD-0332', 'EGD-0337', 'EGD-0338', 'EGD-0340', 'EGD-0344', 'EGD-0349', 'EGD-0351', 'EGD-0352', 'EGD-0356', 'EGD-0357', 'EGD-0363', 'EGD-0369', 'EGD-0377', 'EGD-0378', 'EGD-0382', 'EGD-0387', 'EGD-0389', 'EGD-0390', 'EGD-0394', 'EGD-0401', 'EGD-0410', 'EGD-0411', 'EGD-0415', 'EGD-0417', 'EGD-0420', 'EGD-0421', 'EGD-0426', 'EGD-0434', 'EGD-0439', 'EGD-0450', 'EGD-0461', 'EGD-0472', 'EGD-0474', 'EGD-0479', 'EGD-0480', 'EGD-0486', 'EGD-0487', 'EGD-0490', 'EGD-0495', 'EGD-0499', 'EGD-0502', 'EGD-0505', 'EGD-0508', 'EGD-0509', 'EGD-0511', 'EGD-0512', 'EGD-0514', 'EGD-0515', 'EGD-0516', 'EGD-0521', 'EGD-0526', 'EGD-0531', 'EGD-0537', 'EGD-0541', 'EGD-0545', 'EGD-0553', 'EGD-0564', 'EGD-0565', 'EGD-0567', 'EGD-0568', 'EGD-0572', 'EGD-0577', 'EGD-0579', 'EGD-0585', 'EGD-0595', 'EGD-0600', 'EGD-0601', 'EGD-0604', 'EGD-0606', 'EGD-0611', 'EGD-0612', 'EGD-0625', 'EGD-0629', 'EGD-0631', 'EGD-0636', 'EGD-0647', 'EGD-0656', 'EGD-0661', 'EGD-0664', 'EGD-0668', 'EGD-0669', 'EGD-0675', 'EGD-0689', 'EGD-0692', 'EGD-0700', 'EGD-0705', 'EGD-0709', 'EGD-0710', 'EGD-0720', 'EGD-0725', 'EGD-0728', 'EGD-0730', 'EGD-0744', 'EGD-0753', 'EGD-0757', 'EGD-0758', 'EGD-0762', 'EGD-0771', 'EGD-0772', 'EGD-0773']

# %% [markdown]
# Extracting T1 and masks paths and writting them on a CSV

# %%
""""df = pd.read_csv("Names.csv", header=None)
df["new_column"] = ""
df.to_csv("Names.csv", index=True)
df.to_csv("Names.csv", header=['ID','Image','Mask'], index=True)"""
import pandas as pd

import csv
rows = zip(ID, list1, list2)

with open('quintointento.csv', "w") as f:
    writer = csv.writer(f)
    for row in rows:
        writer.writerow(row)


df = pd.read_csv("quintointento.csv", header=None)
df.to_csv("quintointento.csv", index=True)
df.to_csv("quintointento.csv", header=['ID','Image','Mask'], index=True)

# %%
# Additonally, store the location of the example parameter file, stored in \pyradiomics\bin
paramPath = '/Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml'
inputCSV= '/Users/vegavazquez/Downloads/TFG/quintointento.csv'
print ("Parameter file, absolute path:", os.path.abspath(paramPath))
print ("Paths file, absolute path:", os.path.abspath(inputCSV))
# Out:
# Parameter file, absolute path: /Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml
# Paths file, absolute path: /Users/vegavazquez/Downloads/TFG/quintointento.csv

# %%
outPath = '/Users/vegavazquez/Downloads/TFG'
outputFilepath = os.path.join(outPath, 'radiomics_features.csv')
outputFilepath2=os.path.join(outPath, 'radiomics_features_filtered.csv')
progress_filename = os.path.join(outPath, 'pyrad_log.txt')
print(outputFilepath)
os.path.exists(outputFilepath)
#os.path.exists(progress_filename)
# Out:
# /Users/vegavazquez/Downloads/TFG/radiomics_features.csv
# True

# %%
from __future__ import print_function

import logging
import os

import pandas
import SimpleITK as sitk

import radiomics
from radiomics import featureextractor

# %%
# Configure logging
rLogger = logging.getLogger('radiomics')
# Create handler for writing to log file
handler = logging.FileHandler(filename=progress_filename, mode='w')
handler.setFormatter(logging.Formatter('%(levelname)s:%(name)s: %(message)s'))
rLogger.addHandler(handler)

# %%
# Initialize logging for batch log messages
logger = rLogger.getChild('batch')
# Set verbosity level for output to stderr (default level = WARNING)
radiomics.setVerbosity(logging.INFO)
logger.info('pyradiomics version: %s', radiomics.__version__)
logger.info('Loading CSV')
# Out:
# pyradiomics version: v3.0.1
# Loading CSV

# %% [markdown]
# USING PANDAS

# %% [markdown]
#    reading paths to T1

# %%
try:
    # Use pandas to read and transpose ('.T') the input data
    # The transposition is needed so that each column represents one test case. This is easier for iteration over
    # the input cases
    flists = pandas.read_csv(inputCSV).T
except Exception:
    logger.error('CSV READ FAILED', exc_info=True)
    exit(-1)

# %%
from radiomics import firstorder, getTestCase, glcm, glrlm, glszm, imageoperations, shape

# %%
logger.info('Loading Done')
logger.info('Patients: %d', len(flists.columns)) #ALL PATIENTS
# Out:
# Loading Done
# Patients: 169

# %%
if os.path.isfile(paramPath):
    extractor = featureextractor.RadiomicsFeatureExtractor(paramPath)
else:  # Parameter file not found, use hardcoded settings instead
    settings = {}
    settings['binWidth'] = 25
    settings['resampledPixelSpacing'] = None  # [3,3,3]
    settings['interpolator'] = sitk.sitkBSpline
    settings['enableCExtensions'] = True

    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    # extractor.enableInputImages(wavelet= {'level': 2})
# Out:
# Loading parameter file /Users/vegavazquez/Downloads/TFG/pyradiomics-master/examples/exampleSettings/Params.yaml

# %%
logger.info('Enabled input images types: %s', extractor.enabledImagetypes)
logger.info('Enabled features: %s', extractor.enableFeatureClassByName)
logger.info('Current settings: %s', extractor.settings)
logger.info('show shape features: %s', extractor.enableAllFeatures)
# Out:
# Enabled input images types: {'Original': {}}
# Enabled features: <bound method RadiomicsFeatureExtractor.enableFeatureClassByName of <radiomics.featureextractor.RadiomicsFeatureExtractor object at 0x7fdf7543a8e0>>
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'weightingNorm': None}
# show shape features: <bound method RadiomicsFeatureExtractor.enableAllFeatures of <radiomics.featureextractor.RadiomicsFeatureExtractor object at 0x7fdf7543a8e0>>

# %%
# Instantiate a pandas data frame to hold the results of all patients
results = pandas.DataFrame()

# %%
import pandas as pd

# %%
df=pd.read_csv(inputCSV)
df.head()
# Out:
#    Unnamed: 0        ID                                              Image  \
# 0           0  EGD-0004  /Users/vegavazquez/Downloads/pruebas_dest/T1/E...
# 1           1  EGD-0008  /Users/vegavazquez/Downloads/pruebas_dest/T1/E...
# 2           2  EGD-0011  /Users/vegavazquez/Downloads/pruebas_dest/T1/E...
# 3           3  EGD-0020  /Users/vegavazquez/Downloads/pruebas_dest/T1/E...
# 4           4  EGD-0022  /Users/vegavazquez/Downloads/pruebas_dest/T1/E...
#
#                                                 Mask
# 0  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 1  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 2  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 3  /Users/vegavazquez/Downloads/pruebas_dest/MASK...
# 4  /Users/vegavazquez/Downloads/pruebas_dest/MASK...

# %% [markdown]
# ## EXTRACTING T1 FEATURES

# %%
for entry in flists:  # Loop over all columns (i.e. the test cases)
    logger.info("(%d/%d) Processing Patient (Image: %s, Mask: %s)",
                entry + 1,
                len(flists),
                flists[entry]['Image'],
                flists[entry]['Mask'])
    imageFilepath = flists[entry]['Image']
    maskFilepath = flists[entry]['Mask']
    label = flists[entry].get('ID', None)
    
    if str(label).isdigit():
        label = int(label)
    else:
        label = None
        
    if (imageFilepath is not None) and (maskFilepath is not None):
        featureVector = flists[entry]  # This is a pandas Series
        featureVector['Image'] = os.path.basename(imageFilepath)
        featureVector['Mask'] = os.path.basename(maskFilepath)
        try:
        # PyRadiomics returns the result as an ordered dictionary, which can be easily converted to a pandas Series
        # The keys in the dictionary will be used as the index (labels for the rows), with the values of the features
        # as the values in the rows.
            result = pandas.Series(extractor.execute(imageFilepath, maskFilepath, label))
            featureVector = featureVector.append(result)
        except Exception:
            logger.error('FEATURE EXTRACTION FAILED:', exc_info=True)
        # To add the calculated features for this case to our data frame, the series must have a name (which will be the
          # name of the column.
        featureVector.name = entry
          # By specifying an 'outer' join, all calculated features are added to the data frame, including those not
          # calculated for previous cases. This also ensures we don't end up with an empty frame, as for the first patient
          # it is 'joined' with the empty data frame.
        results = results.join(featureVector, how='outer')  # If feature extraction failed, results will be all NaN
    logger.info('Extraction complete, writing CSV')
  # .T transposes the data frame, so that each line will represent one patient, with the extracted features as columns
    results.T.to_csv(outputFilepath, index=False, na_rep='NaN')
    logger.info('CSV writing complete')
# Out:
# (1/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0004_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0004_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (2/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0008_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0008_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (3/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0011_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0011_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (4/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0020_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0020_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (5/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0022_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0022_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (6/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0024_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0024_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (7/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0029_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0029_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (8/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0033_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0033_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (9/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0041_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0041_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (10/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0055_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0055_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (11/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0057_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0057_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (12/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0068_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0068_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (13/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0072_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0072_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (14/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0073_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0073_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (15/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0075_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0075_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (16/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0080_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0080_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (17/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0085_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0085_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (18/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0090_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0090_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (19/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0099_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0099_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (20/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0106_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0106_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (21/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0107_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0107_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (22/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0115_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0115_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (23/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0118_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0118_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (24/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0122_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0122_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (25/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0123_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0123_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (26/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0128_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0128_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (27/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0137_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0137_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (28/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0143_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0143_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (29/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0144_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0144_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (30/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0145_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0145_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (31/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0161_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0161_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (32/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0162_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0162_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (33/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0165_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0165_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (34/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0177_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0177_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (35/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0185_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0185_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (36/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0186_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0186_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (37/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0187_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0187_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (38/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0188_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0188_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (39/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0192_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0192_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (40/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0193_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0193_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (41/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0194_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0194_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (42/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0196_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0196_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (43/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0197_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0197_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (44/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0202_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0202_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (45/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0208_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0208_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (46/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0211_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0211_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (47/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0214_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0214_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (48/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0217_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0217_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (49/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0226_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0226_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (50/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0229_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0229_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (51/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0230_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0230_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (52/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0233_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0233_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (53/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0234_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0234_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (54/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0236_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0236_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (55/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0240_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0240_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (56/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0241_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0241_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (57/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0243_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0243_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (58/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0244_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0244_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (59/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0253_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0253_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (60/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0268_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0268_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (61/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0280_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0280_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (62/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0286_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0286_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (63/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0297_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0297_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (64/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0306_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0306_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (65/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0309_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0309_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# ...
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (149/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0668_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0668_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (150/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0669_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0669_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (151/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0675_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0675_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (152/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0689_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0689_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (153/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0692_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0692_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (154/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0700_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0700_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (155/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0705_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0705_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (156/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0709_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0709_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (157/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0710_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0710_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (158/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0720_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0720_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (159/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0725_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0725_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (160/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0728_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0728_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (161/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0730_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0730_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (162/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0744_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0744_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (163/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0753_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0753_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (164/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0757_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0757_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (165/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0758_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0758_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (166/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0762_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0762_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (167/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0771_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0771_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (168/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0772_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0772_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete
# (169/4) Processing Patient (Image: /Users/vegavazquez/Downloads/pruebas_dest/T1/EGD-0773_T1.nii.gz, Mask: /Users/vegavazquez/Downloads/pruebas_dest/MASKS/EGD-0773_MASK.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_1213/3992130525.py:25: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   featureVector = featureVector.append(result)
# Extraction complete, writing CSV
# CSV writing complete

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import skimage, os
from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from skimage.util import montage as montage2d
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.misc
import numpy as np
from glob import glob
from skimage.io import imread
BASE_IMG_PATH=os.path.join('..','pruebas_dest')

# %%
all_images=glob(os.path.join(BASE_IMG_PATH,'T1','*'))
print(len(all_images))
# Out:
# 169

# %%
all_images.sort()

# %%
all_masks=glob(os.path.join(BASE_IMG_PATH,'MASKS','*'))
print(len(all_masks))
# Out:
# 169

# %%
all_masks.sort()

# %%
# show some of the files
print(len(all_images),' matching files found:',all_images[0], all_masks[0])
# Out:
# 169  matching files found: ../pruebas_dest/T1/EGD-0004_T1.nii.gz ../pruebas_dest/MASKS/EGD-0004_MASK.nii.gz

# %%
# %matplotlib inline
try:
    import nibabel as nib
except:
    raise ImportError('Install NIBABEL')

test_image=nib.load(all_images[0]).get_data()
test_mask=nib.load(all_masks[0]).get_data()
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (12, 6))
ax1.imshow(test_image[test_image.shape[0]//2])
ax1.set_title('Image')
ax2.imshow(test_mask[test_image.shape[0]//2])
ax2.set_title('Mask')
# Out:
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_6643/2466853767.py:7: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   test_image=nib.load(all_images[0]).get_data()
# /var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_6643/2466853767.py:8: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   test_mask=nib.load(all_masks[0]).get_data()
# Text(0.5, 1.0, 'Mask')

# %%
from nilearn import image as nli

# %%
oro.nifti::slice(t1, z = c(60, 80))
# Out:
#   File "/var/folders/8n/65lgx8_521zfk3j4kj4x82br0000gn/T/ipykernel_6643/2961457143.py", line 1
#     oro.nifti::slice(t1, z = c(60, 80))
#               ^
# SyntaxError: invalid syntax

# %%
fig, ax1 = plt.subplots(1,1, figsize = (20, 20))
ax1.imshow(montage2d(test_mask), cmap ='bone')
fig.savefig('mask.png')

# %%
from nilearn import plotting
from nilearn import datasets

# %%
all_masks=all_masks[0]
all_images=all_images[0]
print(all_images)
# Out:
# ../pruebas_dest/T1/EGD-0004_T1.nii.gz

# %%
plotting.plot_anat(all_images , cut_coords=[ 0,0, 0], title='EDG-004_T1')

# %%
plotting.plot_anat(all_masks , cut_coords=[0, 0, 0], title='EDG-004_T1')

# %%
from nilearn.maskers import NiftiMasker

import numpy as np
import matplotlib.pyplot as plt
from nilearn import datasets
from nilearn.maskers import NiftiMasker
from nilearn.mass_univariate import permuted_ols
n_subjects=1
get_anats=True

# %%
# Fetch t-contrasts maps from Nilearn datasets module
localizer_dataset = datasets.fetch_localizer_button_task(
    n_subjects,
    get_anats)

# Anatomical image filename
localizer_anat_filename = all_images

# T-contrast map filename
localizer_tmap_filename = localizer_dataset.tmaps[0]
# Out:
# /opt/anaconda3/envs/TFG/lib/python3.8/site-packages/nilearn/datasets/func.py:764: UserWarning: `legacy_format` will default to `False` in release 0.11. Dataset fetchers will then return pandas dataframes by default instead of recarrays.
#   warnings.warn(_LEGACY_FORMAT_MSG)

# %%
print(localizer_anat_filename)
print(localizer_tmap_filename)
# Out:
# ../pruebas_dest/T1/EGD-0004_T1.nii.gz
# 1/brainomics_localizer/brainomics_data/S02/tmaps_LeftAuditory&VisualClickVsRightAuditory&VisualClick.nii.gz

# %% [markdown]
# We want to visualize statistical t-map on its anatomical image.

# %%
# Visualize statistical t-map on its anatomical image
plotting.plot_stat_map(localizer_tmap_filename, bg_img=localizer_anat_filename,
                       title="Statistical t-map with colorbar")

# %% [markdown]
# ## Plotting statistical maps with glass brain image plot_glass_brain

# %% [markdown]
# In this setting, we show the t-contrast maps obtained from task fMRI datasets during a left vs right button press overlayed on cool glass brain schematics image. plotting.plot_glass_brain will be used here

# %%
# Visualizing with plot_abs=False & threshold=3
plotting.plot_glass_brain(localizer_tmap_filename, 
                          threshold=3,
                          plot_abs=False, 
                          colorbar=True,
                          title='Statistical map with threshold=3')

# %% [markdown]
# Plotting mask over anatomical image

# %%
plotting.plot_roi(all_masks, bg_img=all_images,
                  title="plot_roi")
